# %% [markdown]
# # ANX 603 : Python Programming for Analytics
#
# ## Project Solution
# ## Instructor : Dr. Ali Dag
#
#
# #### Note : Submit .ipynb (this) file to the canvas.
#
# #### Name your .ipynb file as “Yourname_ANX603Project.ipynb" before submitting.
#
# #### While working on the assignment;
#
# Use your judgement
# State your assumptions (what do you understand)
# Solve the problem
# Good Luck !

# %% [markdown]
# ### Introduction
#
#
# Assume that, a professor is teaching an online class, in which he has got 7 students; Student1,... Student7. Of these 7 students, 3 of them (Student1, Student2 and Student3) are undegrad.(UG) students while 4 of them (Student4, Student5, Student6 and Student7) are Grad (G) students.
#
# He wants to create a matrix that represents the students grades. Eventually, he wants the analyze the data in this matrix.
#
# There are 2 exams, 5 Hw assignments and 1 final project in this class.
# Both exams (Exam1, Exam2) are graded out of 100, but the weight of the average of these exams are 40 %. Hws (Hw1,Hw2,....,) are worth graded out of 100 and the weight of the average of these hws are 50 % , and finally the project is graded out of 100, but the weight of the project is 10 %.
#
# The students's final grade is calculated in the following way : (Average of exams * 0.4) +  (Average of Hws * 0.5) + (Project * 0.1).
#
# The student gets "A" if the overall grade is above 90%, "B" if the overall grade is between 80 - 90%, "C" if the overall grade is between 70 - 80%, "D" if the overall grade is between 60 - 70% and finally "D" if the overall grade is below 60%
#
# For example : Let us assume that Student1 has got 80 from Exam1, 90 from Exam2, 100 from Hw1, 80 from Hw2, 90 from Hw3,100 from Hw4, 75 from Hw5 and finally 90 from the Project.
#
# The final grade of Student1 is : ((80+90)/2 * 0.4) + ((100+80+90+100+75)/5 * 0.5) + (90 * 0.1) = 87.5, and ends up with "B".
#
#
# Our job in the first two questions is to help this instructor to design his matrix, and calculate the final grades and the letter grades if these students.

# %% [markdown]
# ### Question 1)
#
# - 1a) Create a dataset that contains Test 1 and Test 2 Scores of these students. Please use random integer number creation between 50 and 100 for each test. (Use np.random.seed(2020)) for your randint number generation so that our results match)
# - 1b)Perform the same action for Hws.
# - 1c)Perform the same action for Project.
#
# (The sample outputs are given below)

# %%
## (1a) Exams 
## make sure to use "2022" for your random number generator i.e.:  np.random.seed(2022) 
## so that you can get the same number as I did..


import numpy as np
import pandas as pd
from numpy.random import randint
np.random.seed(2022)

Exams = pd.DataFrame(randint(50,100,size=(7,2)),index='Student1 Student2 Student3 Student4 Student5 Student6 Student7'.split(),columns='Test1 Test2'.split())

Exams
# Out:
#           Test1  Test2
# Student1     78     95
# Student2     98     99
# Student3     99     98
# Student4     74     68
# Student5     74     66
# Student6     91     83
# Student7     77     61

# %%
## (1b)Hws

## make sure to use "2022" for your random number generator i.e.:  np.random.seed(2022) 
## so that you can get the same number as I did..


np.random.seed(2022)
Hws = pd.DataFrame(randint(50,100,size=(7,5)),index='Student1 Student2 Student3 Student4 Student5 Student6 Student7'.split(),columns='Hw1 Hw2 Hw3 Hw4 Hw5'.split())

Hws
# Out:
#           Hw1  Hw2  Hw3  Hw4  Hw5
# Student1   78   95   98   99   99
# Student2   98   74   68   74   66
# Student3   91   83   77   61   69
# Student4   80   90   61   98   69
# Student5   88   58   64   79   66
# Student6   76   61   80   83   52
# Student7   66   65   73   87   67

# %%
## (1c)Project 
## make sure to use "2022" for your random number generator i.e.:  np.random.seed(2022) 
## so that you can get the same number as I did..

np.random.seed(2022)
Project = pd.DataFrame(randint(50,100,size=(7,1)),index='Student1 Student2 Student3 Student4 Student5 Student6 Student7'.split(),columns='Project'.split())
Project
# Out:
#           Project
# Student1       78
# Student2       95
# Student3       98
# Student4       99
# Student5       99
# Student6       98
# Student7       74

# %%
## grades_1 (after merging/concatenating)

grades_1 = pd.concat([Exams,Hws,Project], axis=1)
grades_1
# Out:
#           Test1  Test2  Hw1  Hw2  Hw3  Hw4  Hw5  Project
# Student1     78     95   78   95   98   99   99       78
# Student2     98     99   98   74   68   74   66       95
# Student3     99     98   91   83   77   61   69       98
# Student4     74     68   80   90   61   98   69       99
# Student5     74     66   88   58   64   79   66       99
# Student6     91     83   76   61   80   83   52       98
# Student7     77     61   66   65   73   87   67       74

# %% [markdown]
# ### Question 2)
#
# - 2a) Calculate the average for the test scores, and create a new variable for the averages.
# - 2b) Perform the same action for Hws.
# - 2c) Re-arrange the column order as given below
#
# (The sample outputs are given below)

# %%
## (2a) Add Test Averages

grades_1['Test Average'] = (grades_1['Test1'] + grades_1['Test2'])/2
grades_1
# Out:
#           Test1  Test2  Hw1  Hw2  Hw3  Hw4  Hw5  Project  Test Average
# Student1     78     95   78   95   98   99   99       78          86.5
# Student2     98     99   98   74   68   74   66       95          98.5
# Student3     99     98   91   83   77   61   69       98          98.5
# Student4     74     68   80   90   61   98   69       99          71.0
# Student5     74     66   88   58   64   79   66       99          70.0
# Student6     91     83   76   61   80   83   52       98          87.0
# Student7     77     61   66   65   73   87   67       74          69.0

# %%
##(2b) Add hw averages

grades_1['Hw Average'] = (grades_1['Hw1'] + grades_1['Hw2']+ grades_1['Hw3'] + grades_1['Hw4']+grades_1['Hw5'])/5
grades_1
# Out:
#           Test1  Test2  Hw1  Hw2  Hw3  Hw4  Hw5  Project  Test Average  \
# Student1     78     95   78   95   98   99   99       78          86.5
# Student2     98     99   98   74   68   74   66       95          98.5
# Student3     99     98   91   83   77   61   69       98          98.5
# Student4     74     68   80   90   61   98   69       99          71.0
# Student5     74     66   88   58   64   79   66       99          70.0
# Student6     91     83   76   61   80   83   52       98          87.0
# Student7     77     61   66   65   73   87   67       74          69.0
#
#           Hw Average
# Student1        93.8
# Student2        76.0
# Student3        76.2
# Student4        79.6
# Student5        71.0
# Student6        70.4
# Student7        71.6

# %%
## (2c) grades_1(columns are reordered)

grades_2 = grades_1[['Test1', 'Test2','Test Average', 'Hw1', 'Hw2','Hw3', 'Hw4', 'Hw5','Hw Average', 'Project']]   
grades_2
# Out:
#           Test1  Test2  Test Average  Hw1  Hw2  Hw3  Hw4  Hw5  Hw Average  \
# Student1     78     95          86.5   78   95   98   99   99        93.8
# Student2     98     99          98.5   98   74   68   74   66        76.0
# Student3     99     98          98.5   91   83   77   61   69        76.2
# Student4     74     68          71.0   80   90   61   98   69        79.6
# Student5     74     66          70.0   88   58   64   79   66        71.0
# Student6     91     83          87.0   76   61   80   83   52        70.4
# Student7     77     61          69.0   66   65   73   87   67        71.6
#
#           Project
# Student1       78
# Student2       95
# Student3       98
# Student4       99
# Student5       99
# Student6       98
# Student7       74

# %% [markdown]
# ### Question 3)
#
# - 3a) Create a variable called "Final Average", with the formula provided at the "Introduction"
# - 3b) Create another variable called "Letter Grade", with the condition/formula provided at the "Introduction"
# - 3c) The instructor believes that "Test Average" is correlated with "Final Average". Determine the "Test Average" of those students whose "Final Average" is above 80.
#
# (The sample outputs are given below)

# %%
## (3a) 

grades_2['Final Average'] = grades_2['Test Average']*0.4 + grades_2['Hw Average']*0.5 + grades_2['Project']*0.1
grades_2
# Out:
# /var/folders/14/yy0dl2ms36s2pyqdflpr71344lvr1p/T/ipykernel_7451/584467369.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grades_2['Final Average'] = grades_2['Test Average']*0.4 + grades_2['Hw Average']*0.5 + grades_2['Project']*0.1
#           Test1  Test2  Test Average  Hw1  Hw2  Hw3  Hw4  Hw5  Hw Average  \
# Student1     78     95          86.5   78   95   98   99   99        93.8
# Student2     98     99          98.5   98   74   68   74   66        76.0
# Student3     99     98          98.5   91   83   77   61   69        76.2
# Student4     74     68          71.0   80   90   61   98   69        79.6
# Student5     74     66          70.0   88   58   64   79   66        71.0
# ...

# %%
## (3b)

def f(row):
    if row['Final Average'] > 90:
        val = 'A'
    elif row['Final Average'] > 80:
        val = 'B'
    elif row['Final Average'] > 70:
        val = 'C'
    elif row['Final Average'] > 60:
        val = 'D'
    else:
        val = "F"
    return val

# %%
grades_2['Letter Grade'] = grades_2.apply(f, axis=1)
grades_2
# Out:
# /var/folders/14/yy0dl2ms36s2pyqdflpr71344lvr1p/T/ipykernel_7451/2743886563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grades_2['Letter Grade'] = grades_2.apply(f, axis=1)
#           Test1  Test2  Test Average  Hw1  Hw2  Hw3  Hw4  Hw5  Hw Average  \
# Student1     78     95          86.5   78   95   98   99   99        93.8
# Student2     98     99          98.5   98   74   68   74   66        76.0
# Student3     99     98          98.5   91   83   77   61   69        76.2
# Student4     74     68          71.0   80   90   61   98   69        79.6
# Student5     74     66          70.0   88   58   64   79   66        71.0
# Student6     91     83          87.0   76   61   80   83   52        70.4
# ...

# %%
## (3c)

grades_2[grades_2['Final Average']> 80]['Test Average']
# Out:
# Student1    86.5
# Student2    98.5
# Student3    98.5
# Name: Test Average, dtype: float64

# %% [markdown]
# ### Question 4)
#
# - 4a) Sort the data from Max to Min number based on "Final Average" variable
#
# - 4b) Determine the students whose both "Final Average" and "Test Average" scores are higher than 80.
#
#
#
# (The sample outputs are given below)

# %%
## 4(a)

grades_2.sort_values('Final Average', ascending=False)
# Out:
#           Test1  Test2  Test Average  Hw1  Hw2  Hw3  Hw4  Hw5  Hw Average  \
# Student1     78     95          86.5   78   95   98   99   99        93.8
# Student3     99     98          98.5   91   83   77   61   69        76.2
# Student2     98     99          98.5   98   74   68   74   66        76.0
# Student6     91     83          87.0   76   61   80   83   52        70.4
# Student4     74     68          71.0   80   90   61   98   69        79.6
# Student5     74     66          70.0   88   58   64   79   66        71.0
# Student7     77     61          69.0   66   65   73   87   67        71.6
#
#           Project  Final Average Letter Grade
# Student1       78           89.3            B
# Student3       98           87.3            B
# Student2       95           86.9            B
# Student6       98           79.8            C
# Student4       99           78.1            C
# Student5       99           73.4            C
# Student7       74           70.8            C

# %%
## 4(b)

grades_3= grades_2[(grades_2['Final Average']>80) & (grades_2['Test Average'] >80)]
grades_3
# Out:
#           Test1  Test2  Test Average  Hw1  Hw2  Hw3  Hw4  Hw5  Hw Average  \
# Student1     78     95          86.5   78   95   98   99   99        93.8
# Student2     98     99          98.5   98   74   68   74   66        76.0
# Student3     99     98          98.5   91   83   77   61   69        76.2
#
#           Project  Final Average Letter Grade
# Student1       78           89.3            B
# Student2       95           86.9            B
# Student3       98           87.3            B

# %% [markdown]
# ### Question 5)
#
# - 5a) Create histograms for "Test1" and "Final Average" variables,as given below
# - 5b) Create a scatter plot to show the relation between th "Test Average" and "Final Average" variables,as given below
# - 5c) Create box plots  for "Test Average" and "Final Average" variables,as given below
#
# (The sample outputs are given below)

# %%
## 5(a)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = grades_2['Test Average']
y = grades_2['Final Average']

fig, ax = plt.subplots(1,2, figsize=(12,6))

ax[0].hist(x)
ax[0].set_xlabel('Test Average')
ax[0].set_ylabel('Frequency')

ax[1].hist(y)
ax[1].set_xlabel('Final Average')
ax[1].set_ylabel('Frequency');

# %%
## 5(b)

grades_2.plot.scatter('Test Average','Final Average')
# Out:
# <AxesSubplot:xlabel='Test Average', ylabel='Final Average'>

# %%
## 5(c)

fig, ax = plt.subplots(1,2,figsize=(9,5))

labels = ['Test1','Final Average']
x = grades_2['Test1']
y = grades_2['Final Average']


ax[0].boxplot(x)
ax[0].set_xticklabels([]) 
ax[0].set_xlabel('Test1')
ax[0].set_ylabel('Score')

ax[1].boxplot(y)
ax[1].set_xticklabels([])
ax[1].set_xlabel('Final Average')
ax[1].set_ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# ## Good Luck !
